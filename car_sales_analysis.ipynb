# %% [markdown]
# **Assignment**  **-**  **Pandas and Visualization using sns and plt**
#
# Car Sales Data Analysis - Pandas, Seaborn & Matplotlib

# %%
import pandas as pd
df = pd.read_csv("car_sales_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         50000 non-null  object
#  1   Model                50000 non-null  object
#  2   Engine size          50000 non-null  float64
#  3   Fuel type            50000 non-null  object
#  4   Year of manufacture  50000 non-null  int64
#  5   Mileage              50000 non-null  int64
#  6   Price                50000 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.7+ MB

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Engine size', 'Fuel type',
#        'Year of manufacture', 'Mileage', 'Price'],
#       dtype='object')

# %%
df.shape
# Out:
# (50000, 7)

# %%
df.head()
# Out:
#   Manufacturer       Model  Engine size Fuel type  Year of manufacture  \
# 0         Ford      Fiesta          1.0    Petrol                 2002
# 1      Porsche  718 Cayman          4.0    Petrol                 2016
# 2         Ford      Mondeo          1.6    Diesel                 2014
# 3       Toyota        RAV4          1.8    Hybrid                 1988
# 4           VW        Polo          1.0    Petrol                 2006
#
#    Mileage  Price
# 0   127300   3074
# 1    57850  49704
# 2    39190  24072
# 3   210814   1705
# 4   127869   4101

# %%
df.describe()
# Out:
#         Engine size  Year of manufacture        Mileage          Price
# count  50000.000000         50000.000000   50000.000000   50000.000000
# mean       1.773058          2004.209440  112497.320700   13828.903160
# std        0.734108             9.645965   71632.515602   16416.681336
# min        1.000000          1984.000000     630.000000      76.000000
# 25%        1.400000          1996.000000   54352.250000    3060.750000
# 50%        1.600000          2004.000000  100987.500000    7971.500000
# 75%        2.000000          2012.000000  158601.000000   19026.500000
# max        5.000000          2022.000000  453537.000000  168081.000000

# %%
df.tail()
# Out:
#       Manufacturer   Model  Engine size Fuel type  Year of manufacture  \
# 49995          BMW      M5          5.0    Petrol                 2018
# 49996       Toyota   Prius          1.8    Hybrid                 2003
# 49997         Ford  Mondeo          1.6    Diesel                 2022
# 49998         Ford   Focus          1.0    Diesel                 2016
# 49999           VW    Golf          1.4    Diesel                 2012
#
#        Mileage   Price
# 49995    28664  113006
# 49996   105120    9430
# 49997     4030   49852
# 49998    26468   23630
# 49999   109300   10400

# %%
# using iloc and loc
# to access first row
df.iloc[0]
# Out:
# Manufacturer             Ford
# Model                  Fiesta
# Engine size               1.0
# Fuel type              Petrol
# Year of manufacture      2002
# Mileage                127300
# Price                    3074
# Name: 0, dtype: object

# %%
# slicing
df.iloc[0:20, :]
# Out:
#    Manufacturer       Model  Engine size Fuel type  Year of manufacture  \
# 0          Ford      Fiesta          1.0    Petrol                 2002
# 1       Porsche  718 Cayman          4.0    Petrol                 2016
# 2          Ford      Mondeo          1.6    Diesel                 2014
# 3        Toyota        RAV4          1.8    Hybrid                 1988
# 4            VW        Polo          1.0    Petrol                 2006
# 5          Ford       Focus          1.4    Petrol                 2018
# 6          Ford      Mondeo          1.8    Diesel                 2010
# 7        Toyota       Prius          1.4    Hybrid                 2015
# 8            VW        Polo          1.2    Petrol                 2012
# 9          Ford       Focus          2.0    Diesel                 1992
# 10           VW        Golf          2.0    Diesel                 2014
# 11          BMW          Z4          2.0    Petrol                 1990
# ...

# %%
# slicing
df.iloc[0:20, 0:4]
# Out:
#    Manufacturer       Model  Engine size Fuel type
# 0          Ford      Fiesta          1.0    Petrol
# 1       Porsche  718 Cayman          4.0    Petrol
# 2          Ford      Mondeo          1.6    Diesel
# 3        Toyota        RAV4          1.8    Hybrid
# 4            VW        Polo          1.0    Petrol
# 5          Ford       Focus          1.4    Petrol
# 6          Ford      Mondeo          1.8    Diesel
# 7        Toyota       Prius          1.4    Hybrid
# 8            VW        Polo          1.2    Petrol
# 9          Ford       Focus          2.0    Diesel
# 10           VW        Golf          2.0    Diesel
# 11          BMW          Z4          2.0    Petrol
# 12           VW        Golf          1.2    Diesel
# 13       Toyota        RAV4          2.2    Petrol
# 14       Toyota       Yaris          1.4    Petrol
# 15           VW        Golf          1.6    Diesel
# 16       Toyota        RAV4          2.4    Hybrid
# ...

# %%
# slicing
df.iloc[0:10, 0::2]
# Out:
#   Manufacturer  Engine size  Year of manufacture  Price
# 0         Ford          1.0                 2002   3074
# 1      Porsche          4.0                 2016  49704
# 2         Ford          1.6                 2014  24072
# 3       Toyota          1.8                 1988   1705
# 4           VW          1.0                 2006   4101
# 5         Ford          1.4                 2018  29204
# 6         Ford          1.8                 2010  14350
# 7       Toyota          1.4                 2015  30297
# 8           VW          1.2                 2012   9977
# 9         Ford          2.0                 1992   1049

# %%
#using the loc
Ford_cars = df.loc[df['Manufacturer'] == 'Ford']
Ford_cars
# Out:
#       Manufacturer   Model  Engine size Fuel type  Year of manufacture  \
# 0             Ford  Fiesta          1.0    Petrol                 2002
# 2             Ford  Mondeo          1.6    Diesel                 2014
# 5             Ford   Focus          1.4    Petrol                 2018
# 6             Ford  Mondeo          1.8    Diesel                 2010
# 9             Ford   Focus          2.0    Diesel                 1992
# ...            ...     ...          ...       ...                  ...
# 49988         Ford  Mondeo          1.6    Diesel                 1990
# 49989         Ford  Fiesta          1.2    Diesel                 2000
# 49993         Ford  Mondeo          1.8    Petrol                 2003
# 49997         Ford  Mondeo          1.6    Diesel                 2022
# 49998         Ford   Focus          1.0    Diesel                 2016
#
#        Mileage  Price
# 0       127300   3074
# 2        39190  24072
# 5        33603  29204
# ...

# %%
Biggest_engine_size = df.loc[df['Engine size'] == 5 ]
Biggest_engine_size
# Out:
#       Manufacturer Model  Engine size Fuel type  Year of manufacture  Mileage  \
# 236            BMW    M5          5.0    Petrol                 2016    42059
# 383            BMW    M5          5.0    Petrol                 1999    82222
# 555            BMW    M5          5.0    Petrol                 1996   140252
# 639            BMW    M5          5.0    Petrol                 2011    76754
# 663            BMW    M5          5.0    Petrol                 2000   122612
# ...            ...   ...          ...       ...                  ...      ...
# 49631          BMW    M5          5.0    Petrol                 1992   187785
# 49722          BMW    M5          5.0    Petrol                 1992   226908
# 49862          BMW    M5          5.0    Petrol                 2010   100047
# 49867          BMW    M5          5.0    Petrol                 2013    78376
# 49995          BMW    M5          5.0    Petrol                 2018    28664
#
#         Price
# 236     91415
# ...

# %%
len(Biggest_engine_size)
# Out:
# 525

# %%
Biggest_engine_size.shape
# Out:
# (525, 7)

# %%
df["Year of manufacture"] = pd.to_datetime(df["Year of manufacture"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         50000 non-null  object
#  1   Model                50000 non-null  object
#  2   Engine size          50000 non-null  float64
#  3   Fuel type            50000 non-null  object
#  4   Year of manufacture  50000 non-null  datetime64[ns]
#  5   Mileage              50000 non-null  int64
#  6   Price                50000 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 2.7+ MB

# %%
# New column for price categories 

def categorize_price(price):
    if price < 2000:
        return 'Second_hand'
    elif price <10000:
        return 'Cheap'
    elif 10000< price < 14000:
        return 'Mid-range'
    elif 14000<price < 17000:
        return 'Premium'
    else:
        return 'Luxury'

df["Price_Category"] = df["Price"].apply(lambda x: categorize_price(x))

df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Engine size', 'Fuel type',
#        'Year of manufacture', 'Mileage', 'Price', 'Price_Category'],
#       dtype='object')

# %%
df.head()
# Out:
#   Manufacturer       Model  Engine size Fuel type  \
# 0         Ford      Fiesta          1.0    Petrol
# 1      Porsche  718 Cayman          4.0    Petrol
# 2         Ford      Mondeo          1.6    Diesel
# 3       Toyota        RAV4          1.8    Hybrid
# 4           VW        Polo          1.0    Petrol
#
#             Year of manufacture  Mileage  Price Price_Category
# 0 1970-01-01 00:00:00.000002002   127300   3074          Cheap
# 1 1970-01-01 00:00:00.000002016    57850  49704         Luxury
# 2 1970-01-01 00:00:00.000002014    39190  24072         Luxury
# 3 1970-01-01 00:00:00.000001988   210814   1705    Second_hand
# 4 1970-01-01 00:00:00.000002006   127869   4101          Cheap

# %%
df.loc[df['Price_Category']  == 'Second_hand']
# Out:
#       Manufacturer  Model  Engine size Fuel type  \
# 3           Toyota   RAV4          1.8    Hybrid
# 9             Ford  Focus          2.0    Diesel
# 11             BMW     Z4          2.0    Petrol
# 15              VW   Golf          1.6    Diesel
# 17          Toyota  Yaris          1.2    Petrol
# ...            ...    ...          ...       ...
# 49946           VW   Polo          1.0    Petrol
# 49961       Toyota  Yaris          1.4    Hybrid
# 49965       Toyota  Yaris          1.2    Hybrid
# 49968           VW   Golf          1.4    Diesel
# 49972           VW   Polo          1.0    Petrol
#
#                 Year of manufacture  Mileage  Price Price_Category
# 3     1970-01-01 00:00:00.000001988   210814   1705    Second_hand
# 9     1970-01-01 00:00:00.000001992   262514   1049    Second_hand
# 11    1970-01-01 00:00:00.000001990   293666    719    Second_hand
# 15    1970-01-01 00:00:00.000001989   222390    933    Second_hand
# ...

# %% [markdown]
# **Visualization**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Histogram of car prices

plt.figure(figsize=(8,4))
sns.histplot(df["Price"], bins=20, kde=True)
plt.title("Distribution of Car Prices", color = 'blue')
plt.show()

# %%
# Bar plot: Average Price per Manufacturer

sns.barplot(data=df, x="Manufacturer", y="Price", estimator="mean", color = 'cyan')
plt.title("Average Price by Manufacturer")
plt.xticks(rotation=45)
plt.show()

# %%
# Scatter plot: Mileage vs Price
plt.figure(figsize=(8,4))
sns.scatterplot(data=df, x="Mileage", y="Price", hue="Fuel type")
plt.title("Mileage vs Price by Fuel Type")
plt.show()

# %% [markdown]
# Matplotlib

# %%
# Histogram
plt.figure(figsize=(7,4))
plt.hist(df["Price"], bins=20, color="skyblue", edgecolor="black")
plt.title("Distribution of Car Prices")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %%
# Scatter plot
plt.figure(figsize=(8,4))
plt.scatter(df["Mileage"], df["Price"], c="red")
plt.title("Mileage vs Price")
plt.xlabel("Mileage")
plt.ylabel("Price")
plt.show()

# %%
# Bar plot (Average Price per Manufacturer)
avg_price = df.groupby("Manufacturer")["Price"].mean()
plt.figure(figsize=(8,4))
avg_price.plot(kind="bar", color="green")
plt.title("Average Price by Manufacturer")
plt.ylabel("Average Price")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot( data=df, x="Manufacturer", hue='Manufacturer', palette="Set2" )
plt.title("Number of cars per manufacturer")
plt.xlabel("manufacturer")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot( data=df, x="Price_Category", hue="Price_Category", palette="Set2")
plt.title("Number of Cars in Each Price Category")
plt.show()

# %%
sns.boxplot(x="Fuel type", y="Mileage", data=df, hue ='Fuel type', palette="Pastel1")
plt.title("Mileage Distribution by Fuel Type", color='blue')
plt.xlabel("Fuel Type")
plt.ylabel("Mileage")
plt.show()
